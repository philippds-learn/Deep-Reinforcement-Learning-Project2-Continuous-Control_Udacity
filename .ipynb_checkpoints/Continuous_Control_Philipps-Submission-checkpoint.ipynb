# %% [markdown]
# # Continuous Control
#
# ---
#
# In this notebook, you will learn how to use the Unity ML-Agents environment for the second project of the [Deep Reinforcement Learning Nanodegree](https://www.udacity.com/course/deep-reinforcement-learning-nanodegree--nd893) program.
#
# ### 1. Start the Environment
#
# We begin by importing the necessary packages.  If the code cell below returns an error, please revisit the project instructions to double-check that you have installed [Unity ML-Agents](https://github.com/Unity-Technologies/ml-agents/blob/master/docs/Installation.md) and [NumPy](http://www.numpy.org/).

# %%
# Check if jupyter notebook is using gpu
import torch
torch.cuda.current_device()
torch.cuda.device(0)
torch.cuda.device_count()
torch.cuda.get_device_name(0)
torch.cuda.is_available()

# %%
from unityagents import UnityEnvironment
import numpy as np
from collections import deque
import numpy as np
import matplotlib.pyplot as plt
import torch
import time

from ddpg_agent import Agent

# %% [markdown]
# Next, we will start the environment!  **_Before running the code cell below_**, change the `file_name` parameter to match the location of the Unity environment that you downloaded.
#
# - **Mac**: `"path/to/Reacher.app"`
# - **Windows** (x86): `"path/to/Reacher_Windows_x86/Reacher.exe"`
# - **Windows** (x86_64): `"path/to/Reacher_Windows_x86_64/Reacher.exe"`
# - **Linux** (x86): `"path/to/Reacher_Linux/Reacher.x86"`
# - **Linux** (x86_64): `"path/to/Reacher_Linux/Reacher.x86_64"`
# - **Linux** (x86, headless): `"path/to/Reacher_Linux_NoVis/Reacher.x86"`
# - **Linux** (x86_64, headless): `"path/to/Reacher_Linux_NoVis/Reacher.x86_64"`
#
# For instance, if you are using a Mac, then you downloaded `Reacher.app`.  If this file is in the same folder as the notebook, then the line below should appear as follows:
# ```
# env = UnityEnvironment(file_name="Reacher.app")
# ```

# %%
env = UnityEnvironment(file_name='Reacher_Windows_x86_64/Reacher.exe')
# Out:
# INFO:unityagents:
# 'Academy' started successfully!
# Unity Academy name: Academy
#         Number of Brains: 1
#         Number of External Brains : 1
#         Lesson number : 0
#         Reset Parameters :
# 		goal_speed -> 1.0
# 		goal_size -> 5.0
# Unity brain name: ReacherBrain
#         Number of Visual Observations (per agent): 0
#         Vector Observation space type: continuous
#         Vector Observation space size (per agent): 33
#         Number of stacked Vector Observation: 1
#         Vector Action space type: continuous
#         Vector Action space size (per agent): 4
#         Vector Action descriptions: , , ,

# %% [markdown]
# Environments contain **_brains_** which are responsible for deciding the actions of their associated agents. Here we check for the first brain available, and set it as the default brain we will be controlling from Python.

# %%
# get the default brain
brain_name = env.brain_names[0]
brain = env.brains[brain_name]

# %% [markdown]
# ### 2. Examine the State and Action Spaces
#
# In this environment, a double-jointed arm can move to target locations. A reward of `+0.1` is provided for each step that the agent's hand is in the goal location. Thus, the goal of your agent is to maintain its position at the target location for as many time steps as possible.
#
# The observation space consists of `33` variables corresponding to position, rotation, velocity, and angular velocities of the arm.  Each action is a vector with four numbers, corresponding to torque applicable to two joints.  Every entry in the action vector must be a number between `-1` and `1`.
#
# Run the code cell below to print some information about the environment.

# %%
# reset the environment
env_info = env.reset(train_mode=True)[brain_name]

# number of agents
num_agents = len(env_info.agents)
print('Number of agents:', num_agents)

# size of each action
action_size = brain.vector_action_space_size
print('Size of each action:', action_size)

# examine the state space 
states = env_info.vector_observations
state_size = states.shape[1]
print('There are {} agents. Each observes a state with length: {}'.format(states.shape[0], state_size))
print('The state for the first agent looks like:', states[0])
# Out:
# Number of agents: 20
# Size of each action: 4
# There are 20 agents. Each observes a state with length: 33
# The state for the first agent looks like: [ 0.00000000e+00 -4.00000000e+00  0.00000000e+00  1.00000000e+00
#  -0.00000000e+00 -0.00000000e+00 -4.37113883e-08  0.00000000e+00
#   0.00000000e+00  0.00000000e+00  0.00000000e+00  0.00000000e+00
#   0.00000000e+00  0.00000000e+00 -1.00000000e+01  0.00000000e+00
#   1.00000000e+00 -0.00000000e+00 -0.00000000e+00 -4.37113883e-08
#   0.00000000e+00  0.00000000e+00  0.00000000e+00  0.00000000e+00
#   0.00000000e+00  0.00000000e+00  5.75471878e+00 -1.00000000e+00
#   5.55726624e+00  0.00000000e+00  1.00000000e+00  0.00000000e+00
#  -1.68164849e-01]

# %% [markdown]
# ### 3. Take Random Actions in the Environment
#
# In the next code cell, you will learn how to use the Python API to control the agent and receive feedback from the environment.
#
# Once this cell is executed, you will watch the agent's performance, if it selects an action at random with each time step.  A window should pop up that allows you to observe the agent, as it moves through the environment.
#
# Of course, as part of the project, you'll have to change the code so that the agent is able to use its experience to gradually choose better actions when interacting with the environment!

# %%
env_info = env.reset(train_mode=False)[brain_name]     # reset the environment    
states = env_info.vector_observations                  # get the current state (for each agent)
scores = np.zeros(num_agents)                          # initialize the score (for each agent)
while True:
    actions = np.random.randn(num_agents, action_size) # select an action (for each agent)
    actions = np.clip(actions, -1, 1)                  # all actions between -1 and 1
    env_info = env.step(actions)[brain_name]           # send all actions to tne environment
    next_states = env_info.vector_observations         # get next state (for each agent)
    rewards = env_info.rewards                         # get reward (for each agent)
    dones = env_info.local_done                        # see if episode finished
    scores += env_info.rewards                         # update the score (for each agent)
    states = next_states                               # roll over states to next time step
    if np.any(dones):                                  # exit loop if episode finished
        break
print('Total score (averaged over agents) this episode: {}'.format(np.mean(scores)))

# %% [markdown]
# When finished, you can close the environment.

# %%
env.close()

# %% [markdown]
# ### 4. It's Your Turn!
#
# Now it's your turn to train your own agent to solve the environment!  When training the environment, set `train_mode=True`, so that the line for resetting the environment looks like the following:
# ```python
# env_info = env.reset(train_mode=True)[brain_name]
# ```

# %%
def ddpg(n_episodes=200):
    """
    Params
    ======
        n_episodes (int): maximum number of training episodes
        max_t (int): maximum number of timesteps per episode
        print_every (int): print scores every n-th episode
    """
    """
    env_info = env.reset(train_mode=False)[brain_name]     # reset the environment    
    states = env_info.vector_observations                  # get the current state (for each agent)
    scores = np.zeros(num_agents)                          # initialize the score (for each agent)
    while True:
        actions = np.random.randn(num_agents, action_size) # select an action (for each agent)
        actions = np.clip(actions, -1, 1)                  # all actions between -1 and 1
        env_info = env.step(actions)[brain_name]           # send all actions to tne environment
        next_states = env_info.vector_observations         # get next state (for each agent)
        rewards = env_info.rewards                         # get reward (for each agent)
        dones = env_info.local_done                        # see if episode finished
        scores += env_info.rewards                         # update the score (for each agent)
        states = next_states                               # roll over states to next time step
        if np.any(dones):                                  # exit loop if episode finished
            break
    print('Total score (averaged over agents) this episode: {}'.format(np.mean(scores)))
    """
    scores = []
    scores_window = deque(maxlen=100)
    training_starting_time = time.time()
    
    # loop through all episodes
    for i_episode in range(1, n_episodes+1):
        # get time current time
        episode_starting_time = time.time()
        
        env_info = env.reset(train_mode=True)[brain_name]      # reset the environment        
        states = env_info.vector_observations                  # get the current state (for each agent)        
        agent.reset()         
        score = np.zeros(num_agents)                           # initialize the score (for each agent)
        
        # loop through all time steps in episode
        while True:
            # define actions
            actions = agent.act(states)
            
            # get next states, rewards and done from environment
            env_info = env.step(actions)[brain_name]           # send all actions to tne environment
            next_states = env_info.vector_observations         # get next state (for each agent)
            rewards = env_info.rewards                         # get reward (for each agent)
            dones = env_info.local_done                        # see if episode finished
            
            # agents take step
            agent.step(states, actions, rewards, next_states, dones)
            
            score += rewards                                   # update the score (for each agent)
            states = next_states                               # roll over states to next time step

            if np.any(dones):                                  # exit loop if episode finished 
                break
        
        scores.append(np.mean(score))
        scores_window.append(np.mean(score))
        
        torch.save(agent.actor_local.state_dict(), 'checkpoint_actor.pth')
        torch.save(agent.critic_local.state_dict(), 'checkpoint_critic.pth')
        
        elapsed_training_time = time.time() - training_starting_time
        elapsed_training_time_str = time.strftime('%Mm%Ss', time.gmtime(elapsed_training_time))
        
        elapsed_episode_time = time.time() - episode_starting_time
        elapsed_episode_time_str = time.strftime('%Mm%Ss', time.gmtime(elapsed_episode_time))
        
        print('\rTime elapsed since training started: {}'.format(elapsed_training_time_str))
        print('\rEpisode {} took: {}'.format(i_episode, elapsed_episode_time_str))        
        print('\rEpisode: {} - Score: {} - tAverage Score: {}'.format(i_episode, np.mean(score), np.mean(scores_window)))  
        
        if np.mean(scores_window) >= 30.0:
            print('\nEnvironment solved in {} episodes - Average Score: {}'.format(i_episode, np.mean(scores_window)))
            break
            
    return scores

# %%
agent = Agent(state_size=33, action_size=4, random_seed=0, num_agents=num_agents)
scores = ddpg()
# Out:
# Time elapsed since training started: 00m13s
# Episode 1 took: 00m13s
# Episode: 1 - Score: 0.5714999872259796 - tAverage Score: 0.5714999872259796
# Time elapsed since training started: 00m26s
# Episode 2 took: 00m13s
# Episode: 2 - Score: 0.31899999286979436 - tAverage Score: 0.445249990047887
# Time elapsed since training started: 00m40s
# Episode 3 took: 00m13s
# Episode: 3 - Score: 0.25549999428912995 - tAverage Score: 0.3819999914616347
# Time elapsed since training started: 00m54s
# Episode 4 took: 00m13s
# Episode: 4 - Score: 0.25349999433383347 - tAverage Score: 0.3498749921796844
# Time elapsed since training started: 01m07s
# Episode 5 took: 00m13s
# Episode: 5 - Score: 0.7389999834820629 - tAverage Score: 0.42769999044016005
# Time elapsed since training started: 01m21s
# Episode 6 took: 00m13s
# Episode: 6 - Score: 0.7349999835714698 - tAverage Score: 0.478916655962045
# Time elapsed since training started: 01m35s
# Episode 7 took: 00m13s
# Episode: 7 - Score: 0.9709999782964587 - tAverage Score: 0.5492142734383899
# Time elapsed since training started: 01m48s
# Episode 8 took: 00m13s
# Episode: 8 - Score: 1.4384999678470194 - tAverage Score: 0.6603749852394686
# Time elapsed since training started: 02m02s
# Episode 9 took: 00m13s
# Episode: 9 - Score: 1.2439999721944333 - tAverage Score: 0.7252222060122424
# Time elapsed since training started: 02m15s
# Episode 10 took: 00m13s
# Episode: 10 - Score: 1.2169999727979302 - tAverage Score: 0.7743999826908112
# Time elapsed since training started: 02m29s
# Episode 11 took: 00m13s
# Episode: 11 - Score: 1.7224999614991248 - tAverage Score: 0.8605908898552034
# Time elapsed since training started: 02m43s
# Episode 12 took: 00m13s
# Episode: 12 - Score: 2.138999952189624 - tAverage Score: 0.9671249783830719
# Time elapsed since training started: 02m56s
# Episode 13 took: 00m13s
# Episode: 13 - Score: 2.5334999433718624 - tAverage Score: 1.0876153603052865
# Time elapsed since training started: 03m10s
# Episode 14 took: 00m13s
# Episode: 14 - Score: 2.7214999391697345 - tAverage Score: 1.204321401652747
# Time elapsed since training started: 03m23s
# Episode 15 took: 00m13s
# Episode: 15 - Score: 2.746499938610941 - tAverage Score: 1.3071333041166266
# Time elapsed since training started: 03m37s
# Episode 16 took: 00m13s
# Episode: 16 - Score: 2.7234999391250314 - tAverage Score: 1.3956562188046517
# Time elapsed since training started: 03m51s
# Episode 17 took: 00m13s
# Episode: 17 - Score: 3.126499930117279 - tAverage Score: 1.4974705547642182
# Time elapsed since training started: 04m04s
# Episode 18 took: 00m13s
# Episode: 18 - Score: 2.624999941326678 - tAverage Score: 1.5601110762399104
# Time elapsed since training started: 04m18s
# Episode 19 took: 00m13s
# Episode: 19 - Score: 4.030499909911304 - tAverage Score: 1.6901315411699838
# Time elapsed since training started: 04m32s
# Episode 20 took: 00m13s
# Episode: 20 - Score: 3.469999922439456 - tAverage Score: 1.7791249602334573
# Time elapsed since training started: 04m45s
# Episode 21 took: 00m13s
# Episode: 21 - Score: 4.782999893091619 - tAverage Score: 1.9221666237028938
# Time elapsed since training started: 04m59s
# Episode 22 took: 00m13s
# Episode: 22 - Score: 4.747499893885106 - tAverage Score: 2.0505908632566308
# Time elapsed since training started: 05m13s
# Episode 23 took: 00m13s
# Episode: 23 - Score: 5.767999871075153 - tAverage Score: 2.212217341857436
# Time elapsed since training started: 05m26s
# Episode 24 took: 00m13s
# Episode: 24 - Score: 6.631999851763249 - tAverage Score: 2.3963749464368447
# Time elapsed since training started: 05m40s
# Episode 25 took: 00m13s
# Episode: 25 - Score: 4.99499988835305 - tAverage Score: 2.500319944113493
# Time elapsed since training started: 05m53s
# Episode 26 took: 00m13s
# Episode: 26 - Score: 6.779499848466367 - tAverage Score: 2.6649037865886034
# Time elapsed since training started: 06m07s
# Episode 27 took: 00m13s
# Episode: 27 - Score: 9.058999797515572 - tAverage Score: 2.9017221573636762
# Time elapsed since training started: 06m21s
# Episode 28 took: 00m13s
# Episode: 28 - Score: 8.539999809116125 - tAverage Score: 3.103089216354835
# Time elapsed since training started: 06m34s
# Episode 29 took: 00m13s
# Episode: 29 - Score: 6.9279998451471325 - tAverage Score: 3.23498268631319
# Time elapsed since training started: 06m48s
# Episode 30 took: 00m13s
# Episode: 30 - Score: 5.462999877892434 - tAverage Score: 3.309249926032498
# Time elapsed since training started: 07m02s
# Episode 31 took: 00m13s
# Episode: 31 - Score: 7.19649983914569 - tAverage Score: 3.43464508452002
# Time elapsed since training started: 07m16s
# Episode 32 took: 00m13s
# Episode: 32 - Score: 8.681999805942178 - tAverage Score: 3.5986249195644633
# Time elapsed since training started: 07m29s
# Episode 33 took: 00m13s
# Episode: 33 - Score: 9.214499794039876 - tAverage Score: 3.7688029460637185
# Time elapsed since training started: 07m43s
# Episode 34 took: 00m13s
# Episode: 34 - Score: 9.473999788239599 - tAverage Score: 3.9366028531865385
# Time elapsed since training started: 07m57s
# Episode 35 took: 00m13s
# Episode: 35 - Score: 10.448499766457825 - tAverage Score: 4.1226570507085745
# Time elapsed since training started: 08m10s
# Episode 36 took: 00m13s
# Episode: 36 - Score: 10.169499772693962 - tAverage Score: 4.290624904097058
# Time elapsed since training started: 08m24s
# Episode 37 took: 00m13s
# Episode: 37 - Score: 10.163499772828072 - tAverage Score: 4.449351251900598
# Time elapsed since training started: 08m38s
# Episode 38 took: 00m13s
# Episode: 38 - Score: 10.332499769050628 - tAverage Score: 4.604170949720336
# Time elapsed since training started: 08m51s
# Episode 39 took: 00m13s
# Episode: 39 - Score: 10.65249976189807 - tAverage Score: 4.75925630387874
# Time elapsed since training started: 09m05s
# Episode 40 took: 00m13s
# Episode: 40 - Score: 11.623999740183354 - tAverage Score: 4.930874889786355
# Time elapsed since training started: 09m19s
# Episode 41 took: 00m13s
# Episode: 41 - Score: 12.34049972416833 - tAverage Score: 5.1115974467225005
# Time elapsed since training started: 09m32s
# Episode 42 took: 00m13s
# Episode: 42 - Score: 11.460999743826687 - tAverage Score: 5.262773691891648
# Time elapsed since training started: 09m46s
# Episode 43 took: 00m13s
# Episode: 43 - Score: 15.840999645926058 - tAverage Score: 5.5087789466366335
# Time elapsed since training started: 10m00s
# Episode 44 took: 00m13s
# Episode: 44 - Score: 11.630499740038067 - tAverage Score: 5.647908964668485
# Time elapsed since training started: 10m13s
# Episode 45 took: 00m13s
# Episode: 45 - Score: 13.293999702855945 - tAverage Score: 5.817822092183762
# Time elapsed since training started: 10m28s
# Episode 46 took: 00m15s
# Episode: 46 - Score: 13.884999689646065 - tAverage Score: 5.9931955182155505
# Time elapsed since training started: 10m42s
# Episode 47 took: 00m13s
# Episode: 47 - Score: 13.03899970855564 - tAverage Score: 6.143106245669595
# Time elapsed since training started: 10m56s
# Episode 48 took: 00m13s
# Episode: 48 - Score: 13.183999705314637 - tAverage Score: 6.289791526078868
# Time elapsed since training started: 11m10s
# Episode 49 took: 00m14s
# Episode: 49 - Score: 13.073499707784503 - tAverage Score: 6.428234550195309
# Time elapsed since training started: 11m24s
# Episode 50 took: 00m13s
# Episode: 50 - Score: 15.352999656833708 - tAverage Score: 6.606729852328077
# Time elapsed since training started: 11m37s
# Episode 51 took: 00m13s
# Episode: 51 - Score: 13.908499689120799 - tAverage Score: 6.749901809912248
# Time elapsed since training started: 11m51s
# Episode 52 took: 00m13s
# Episode: 52 - Score: 15.714999648742378 - tAverage Score: 6.922307537582058
# Time elapsed since training started: 12m05s
# Episode 53 took: 00m13s
# Episode: 53 - Score: 13.415999700129031 - tAverage Score: 7.04483003121502
# Time elapsed since training started: 12m18s
# Episode 54 took: 00m13s
# Episode: 54 - Score: 16.456499632168562 - tAverage Score: 7.219120209010456
# Time elapsed since training started: 12m32s
# Episode 55 took: 00m13s
# Episode: 55 - Score: 15.640499650407582 - tAverage Score: 7.372236198854041
# Time elapsed since training started: 12m46s
# Episode 56 took: 00m13s
# Episode: 56 - Score: 14.887999667227268 - tAverage Score: 7.506446260789276
# Time elapsed since training started: 12m59s
# Episode 57 took: 00m13s
# Episode: 57 - Score: 15.754499647859484 - tAverage Score: 7.651148951790507
# Time elapsed since training started: 13m13s
# Episode 58 took: 00m13s
# Episode: 58 - Score: 17.120499617327006 - tAverage Score: 7.814413618437689
# Time elapsed since training started: 13m27s
# Episode 59 took: 00m13s
# Episode: 59 - Score: 15.875999645143747 - tAverage Score: 7.951050669737791
# Time elapsed since training started: 13m40s
# Episode 60 took: 00m13s
# Episode: 60 - Score: 15.882999644987285 - tAverage Score: 8.083249819325284
# Time elapsed since training started: 13m54s
# Episode 61 took: 00m13s
# Episode: 61 - Score: 18.941499576624484 - tAverage Score: 8.261253913707238
# Time elapsed since training started: 14m08s
# Episode 62 took: 00m13s
# Episode: 62 - Score: 17.066499618534 - tAverage Score: 8.403274005720572
# Time elapsed since training started: 14m21s
# Episode 63 took: 00m13s
# Episode: 63 - Score: 17.07149961842224 - tAverage Score: 8.540864888461869
# Time elapsed since training started: 14m35s
# Episode 64 took: 00m13s
# Episode: 64 - Score: 16.294499635789542 - tAverage Score: 8.662015431388863
# Time elapsed since training started: 14m49s
# Episode 65 took: 00m13s
# Episode: 65 - Score: 16.86949962293729 - tAverage Score: 8.788284418951147
# Time elapsed since training started: 15m02s
# Episode 66 took: 00m13s
# Episode: 66 - Score: 17.931999599188565 - tAverage Score: 8.926825558045651
# Time elapsed since training started: 15m16s
# Episode 67 took: 00m13s
# Episode: 67 - Score: 17.917999599501492 - tAverage Score: 9.061022185530067
# Time elapsed since training started: 15m30s
# Episode 68 took: 00m13s
# Episode: 68 - Score: 18.18199959360063 - tAverage Score: 9.195154206236987
# Time elapsed since training started: 15m43s
# Episode 69 took: 00m13s
# Episode: 69 - Score: 17.855999600887298 - tAverage Score: 9.320673704710181
# Time elapsed since training started: 15m57s
# Episode 70 took: 00m13s
# Episode: 70 - Score: 18.65649958299473 - tAverage Score: 9.454042645828531
# Time elapsed since training started: 16m11s
# Episode 71 took: 00m13s
# Episode: 71 - Score: 18.665499582793565 - tAverage Score: 9.58378147592663
# Time elapsed since training started: 16m25s
# Episode 72 took: 00m13s
# Episode: 72 - Score: 21.424999521113932 - tAverage Score: 9.748242837665344
# Time elapsed since training started: 16m38s
# Episode 73 took: 00m13s
# Episode: 73 - Score: 20.019499552529304 - tAverage Score: 9.888944984444302
# Time elapsed since training started: 16m52s
# Episode 74 took: 00m13s
# Episode: 74 - Score: 17.57999960705638 - tAverage Score: 9.992878155020142
# Time elapsed since training started: 17m06s
# Episode 75 took: 00m13s
# Episode: 75 - Score: 17.437499610241503 - tAverage Score: 10.092139774423092
# Time elapsed since training started: 17m19s
# Episode 76 took: 00m13s
# Episode: 76 - Score: 18.395499588828535 - tAverage Score: 10.201394508823165
# Time elapsed since training started: 17m33s
# Episode 77 took: 00m13s
# Episode: 77 - Score: 17.194499615672974 - tAverage Score: 10.29221405566537
# Time elapsed since training started: 17m47s
# Episode 78 took: 00m13s
# Episode: 78 - Score: 18.59599958434701 - tAverage Score: 10.398672844494623
# Time elapsed since training started: 18m01s
# Episode 79 took: 00m13s
# Episode: 79 - Score: 18.07449959600344 - tAverage Score: 10.495835208437772
# Time elapsed since training started: 18m14s
# Episode 80 took: 00m13s
# Episode: 80 - Score: 18.209499592985956 - tAverage Score: 10.592256013244624
# Time elapsed since training started: 18m28s
# Episode 81 took: 00m13s
# Episode: 81 - Score: 18.978999575786293 - tAverage Score: 10.69579605722662
# Time elapsed since training started: 18m41s
# Episode 82 took: 00m13s
# Episode: 82 - Score: 20.47449954235926 - tAverage Score: 10.815048538752627
# Time elapsed since training started: 18m55s
# Episode 83 took: 00m13s
# Episode: 83 - Score: 18.831499579083175 - tAverage Score: 10.911632286226489
# Time elapsed since training started: 19m09s
# Episode 84 took: 00m13s
# Episode: 84 - Score: 19.563999562710524 - tAverage Score: 11.014636658565584
# Time elapsed since training started: 19m22s
# Episode 85 took: 00m13s
# Episode: 85 - Score: 18.09099959563464 - tAverage Score: 11.097887987236984
# Time elapsed since training started: 19m36s
# Episode 86 took: 00m13s
# Episode: 86 - Score: 18.265999591723084 - tAverage Score: 11.18123812217287
# Time elapsed since training started: 19m50s
# Episode 87 took: 00m13s
# Episode: 87 - Score: 18.74999958090484 - tAverage Score: 11.268235380319215
# Time elapsed since training started: 20m03s
# Episode 88 took: 00m13s
# Episode: 88 - Score: 18.920999577082693 - tAverage Score: 11.355198609827891
# Time elapsed since training started: 20m17s
# Episode 89 took: 00m13s
# Episode: 89 - Score: 17.512999608553947 - tAverage Score: 11.424387385094477
# Time elapsed since training started: 20m31s
# Episode 90 took: 00m13s
# Episode: 90 - Score: 19.818499557022005 - tAverage Score: 11.517655298115892
# Time elapsed since training started: 20m44s
# Episode 91 took: 00m13s
# Episode: 91 - Score: 18.8029995797202 - tAverage Score: 11.59771402648517
# Time elapsed since training started: 20m58s
# Episode 92 took: 00m13s
# Episode: 92 - Score: 18.192499593365937 - tAverage Score: 11.66939647829909
# Time elapsed since training started: 21m12s
# Episode 93 took: 00m13s
# Episode: 93 - Score: 19.56599956266582 - tAverage Score: 11.75430618888368
# Time elapsed since training started: 21m25s
# Episode 94 took: 00m13s
# Episode: 94 - Score: 20.410999543778598 - tAverage Score: 11.846398671382563
# Time elapsed since training started: 21m39s
# Episode 95 took: 00m13s
# Episode: 95 - Score: 20.196499548573048 - tAverage Score: 11.93429447008983
# Time elapsed since training started: 21m53s
# Episode 96 took: 00m13s
# Episode: 96 - Score: 20.731999536603688 - tAverage Score: 12.02593723119935
# Time elapsed since training started: 22m06s
# Episode 97 took: 00m13s
# Episode: 97 - Score: 19.691499559860677 - tAverage Score: 12.104963646958744
# Time elapsed since training started: 22m20s
# Episode 98 took: 00m13s
# Episode: 98 - Score: 20.299499546270816 - tAverage Score: 12.188581360217032
# Time elapsed since training started: 22m34s
# Episode 99 took: 00m13s
# Episode: 99 - Score: 20.532999541051687 - tAverage Score: 12.272868412548695
# Time elapsed since training started: 22m47s
# Episode 100 took: 00m13s
# Episode: 100 - Score: 16.90799962207675 - tAverage Score: 12.319219724643974

# %%
fig = plt.figure()
ax = fig.add_subplot(111)
plt.plot(np.arange(1, len(scores)+1), mean(scores))
plt.ylabel('Score')
plt.xlabel('Episode #')
plt.show()

# %% [markdown]
# When finished, you can close the environment.

# %%
env.close()
